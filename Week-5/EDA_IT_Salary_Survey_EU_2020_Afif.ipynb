# %% [markdown]
# <a href="https://colab.research.google.com/github/afifibd/Machine-Learning/blob/main/Week-5/EDA_IT_Salary_Survey_EU_2020_Afif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama      : Afif Ibadurrahman Jalaluddin
#
# Nim       : 1103210221
#
# Lecture 5 : Explanatory Data Analysis
#
# Dataset : IT Salary Survey EU 2020, Model : EDA
#
# Dokumentasi ChatGPT : https://chat.openai.com/share/6539abce-f363-4db6-899c-001647a9d460

# %% [markdown]
# ChatGPT Prompt : Beri kode untuk mount google drive ke google colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ChatGPT Prompt : Beri kode untuk read dataset as dataframe dengan path "/content/drive/MyDrive/Dataset/IT Salary Survey EU  2020.csv"

# %%
import pandas as pd

# Path dataset di Google Drive
file_path = "/content/drive/MyDrive/Dataset/IT Salary Survey EU 2020.csv"

# Membaca dataset menjadi DataFrame
df = pd.read_csv(file_path)

# Menampilkan DataFrame
df.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
df.head(7)
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
# 5  24/11/2020 11:15:53  32.0   Male  Berlin              DevOps
# 6  24/11/2020 11:16:35  37.0   Male  Berlin  Frontend Developer
#
#    Total years of experience  Years of experience in Germany Seniority level  \
# 0                        5.0                             3.0          Senior
# 1                        7.0                             4.0          Senior
# 2                       12.0                             6.0            Lead
# 3                        4.0                             1.0          Junior
# ...

# %%
df.tail()
# Out:
#                 Timestamp   Age Gender         City  \
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position   Total years of experience  \
# 1248                       Backend Developer                        9.0
# 1249  Researcher/ Consumer Insights Analyst                        10.0
# 1250                   IT Operations Manager                       15.0
# 1251                      Frontend Developer                        7.0
# 1252                                  DevOps                        2.0
#
#       Years of experience in Germany Seniority level  \
# 1248                             5.0          Senior
# 1249                             1.5          Senior
# ...

# %% [markdown]
# ChatGPT Prompt : Beri kode untuk menampilkan informasi ringkas dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %% [markdown]
# ChatGPT Prompt : Beri petunjuk untuk melakukan Exploratory Data Analysis
#
# Exploratory Data Analysis (EDA) adalah proses untuk memahami dataset Anda dengan melakukan analisis awal dan visualisasi data. Berikut adalah langkah-langkah umum yang dapat Anda ikuti untuk melakukan EDA:
#
# 1. **Memahami Data**:
#    - Baca dokumentasi dataset (jika ada) untuk memahami struktur dan konten data.
#    - Tampilkan beberapa baris pertama dataset menggunakan `head()` untuk melihat format dan struktur data.
#    - Gunakan `info()` untuk melihat tipe data dan jumlah nilai non-null dalam setiap kolom.
#
# 2. **Pemrosesan Data Awal**:
#    - Identifikasi dan tangani nilai yang hilang atau yang tidak valid.
#    - Ubah tipe data jika diperlukan (misalnya, tanggal ke tipe data datetime).
#    - Lakukan pemrosesan teks atau pembersihan data lainnya jika diperlukan.
#
# 3. **Statistik Deskriptif**:
#    - Hitung statistik deskriptif seperti mean, median, dan standar deviasi untuk setiap kolom numerik menggunakan `describe()`.
#    - Identifikasi nilai ekstrim, nilai yang hilang, atau anomali lainnya.
#
# 4. **Visualisasi Data**:
#    - Gunakan plot seperti histogram, box plot, dan scatter plot untuk memahami distribusi dan hubungan antar variabel.
#    - Gunakan heatmap untuk memahami korelasi antar variabel numerik.
#    - Buat visualisasi tambahan yang sesuai dengan jenis data Anda, seperti diagram batang untuk data kategorikal atau time series plot untuk data deret waktu.
#
# 5. **Eksplorasi Lebih Lanjut**:
#    - Identifikasi pola atau tren menarik dalam data.
#    - Lakukan analisis univariat dan multivariat untuk memahami hubungan antar variabel.
#    - Jelajahi pertanyaan atau hipotesis awal Anda dengan menggunakan visualisasi dan analisis statistik.
#
# 6. **Ringkasan dan Kesimpulan**:
#    - Ringkas temuan utama Anda.
#    - Berikan interpretasi atas temuan Anda.
#    - Identifikasi pertanyaan baru atau arah penelitian yang mungkin.
#
# Selama proses EDA, Anda juga dapat melakukan iterasi, kembali ke langkah-langkah sebelumnya, atau mengeksplorasi data lebih lanjut seiring dengan memahami lebih dalam tentang dataset Anda. Pemahaman yang baik tentang data adalah kunci untuk menghasilkan wawasan yang berharga dari analisis data.

# %% [markdown]
# ChatGPT Prompt : Beri kode untuk mendapatkan summary statistical dari dataframe

# %%
# Mendapatkan summary statistical dari dataframe
df.describe()
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %% [markdown]
# ChatGPT Prompt : beri kode melihat 5 baris teratas dari fitur-fitur tertentu berikut : "Total years of experience", "Years of experience in Germany", "Yearly bonus + stocks in EUR", "Annual bonus+stocks one year ago. Only answer if staying in same country", "Number of vacation days", "Contract duration", "Company size"

# %%
# List fitur yang ingin ditampilkan
fitur = ["Total years of experience",
         "Years of experience in Germany",
         "Yearly bonus + stocks in EUR",
         "Annual bonus+stocks one year ago. Only answer if staying in same country",
         "Number of vacation days",
         "Сontract duration",
         "Company size"]

# Menampilkan lima baris teratas dari fitur-fitur tertentu
df[fitur].head()
# Out:
#   Total years of experience Years of experience in Germany  \
# 0                         5                              3
# 1                         7                              4
# 2                        12                              6
# 3                         4                              1
# 4                        17                              6
#
#   Yearly bonus + stocks in EUR  \
# 0                         5000
# 1                          NaN
# 2                       120000
# 3                          NaN
# 4                          NaN
#
#   Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                              10000
# 1                                               5000
# 2                                             100000
# 3                                                NaN
# 4                                                NaN
#
#   Number of vacation days   Сontract duration Company size
# ...

# %% [markdown]
# ChatGPT Prompt : Beri kode untuk mengubah fitur-fitur berikut "Total years of experience", "Years of experience in Germany","Yearly bonus + stocks in EUR", "Annual bonus+stocks one year ago. Only answer if staying in same country", "Number of vacation days". bertipe data numerik !

# %%
# List fitur yang ingin diubah menjadi numerik
fitur_numerik = ["Total years of experience",
                 "Years of experience in Germany",
                 "Yearly bonus + stocks in EUR",
                 "Annual bonus+stocks one year ago. Only answer if staying in same country",
                 "Number of vacation days"]

# Mengubah tipe data fitur-fitur menjadi numerik
for fitur in fitur_numerik:
    df[fitur] = pd.to_numeric(df[fitur], errors='coerce')

# Menampilkan lima baris teratas setelah perubahan tipe data
print(df[fitur_numerik].head())
# Out:
#    Total years of experience  Years of experience in Germany  \
# 0                        5.0                             3.0
# 1                        7.0                             4.0
# 2                       12.0                             6.0
# 3                        4.0                             1.0
# 4                       17.0                             6.0
#
#    Yearly bonus + stocks in EUR  \
# 0                        5000.0
# 1                           NaN
# 2                      120000.0
# 3                           NaN
# 4                           NaN
#
#    Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                            10000.0
# 1                                             5000.0
# 2                                           100000.0
# 3                                                NaN
# 4                                                NaN
#
#    Number of vacation days
# ...

# %% [markdown]
# ChatGPT Prompt :
# Beri kode untuk memperbarui nama-nama fitur berikut :
# - 'Total years of experience': 'Total experience'
# - 'Years of experience in Germany': 'Experience in Germany'
# - 'Your main technology / programming language': 'Main programming language'
# - 'Other technologies/programming languages you use often': 'Other programming languages'
# - 'Yearly brutto salary (without bonus and stocks) in EUR': 'Yearly brutto salary'
# -  'Yearly bonus + stocks in EUR': 'Yearly bonus and stocks',
# -  'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country': 'Previous yearly brutto salary'
# - 'Annual bonus+stocks one year ago. Only answer if staying in same country': 'Previous yearly bonus and stocks'
# - 'Number of vacation days': 'Vacation days',
# - 'Main language at work': 'Main work language'
# - 'Have you lost your job due to the coronavirus outbreak?': 'Lost job due to COVID-19'
# - 'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week': 'Kurzarbeit hours per week'
# - 'Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR': 'Additional monetary support in 2020'

# %%
# Dictionary yang berisi mapping nama-nama fitur yang lama ke nama-nama fitur yang baru
nama_fitur_baru = {
    'Total years of experience': 'Total experience',
    'Years of experience in Germany': 'Experience in Germany',
    'Your main technology / programming language': 'Main programming language',
    'Other technologies/programming languages you use often': 'Other programming languages',
    'Yearly brutto salary (without bonus and stocks) in EUR': 'Yearly brutto salary',
    'Yearly bonus + stocks in EUR': 'Yearly bonus and stocks',
    'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country': 'Previous yearly brutto salary',
    'Annual bonus+stocks one year ago. Only answer if staying in same country': 'Previous yearly bonus and stocks',
    'Number of vacation days': 'Vacation days',
    'Main language at work': 'Main work language',
    'Have you lost your job due to the coronavirus outbreak?': 'Lost job due to COVID-19',
    'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week': 'Kurzarbeit hours per week',
    'Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR': 'Additional monetary support in 2020'
}

# Memperbarui nama-nama fitur dalam dataframe
df = df.rename(columns=nama_fitur_baru)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Timestamp                            1253 non-null   object
#  1   Age                                  1226 non-null   float64
#  2   Gender                               1243 non-null   object
#  3   City                                 1253 non-null   object
#  4   Position                             1247 non-null   object
#  5   Total experience                     1230 non-null   float64
#  6   Experience in Germany                1194 non-null   float64
#  7   Seniority level                      1241 non-null   object
#  8   Main programming language            1126 non-null   object
#  9   Other programming languages          1096 non-null   object
#  10  Yearly brutto salary                 1253 non-null   float64
# ...

# %% [markdown]
# ChatGPT Prompt : beri baris untuk menampilkan baris yang memiliki null value

# %%
# Menampilkan baris yang memiliki null value
baris_null = df[df.isnull().any(axis=1)]

# Menampilkan baris yang memiliki null value
baris_null
# Out:
#                 Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1247  18/01/2021 11:50:02  34.0   Male       Zurich
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
#
#                                    Position   Total experience  \
# 0                          Software Engineer               5.0
# 1                          Backend Developer               7.0
# 2                          Software Engineer              12.0
# 3                         Frontend Developer               4.0
# ...

# %% [markdown]
# ChatGPT Prompt : beri kode untuk mengisi baris dari fitur "Kurzarbeit hours per week" yang memiliki null value dengan nilai "0"

# %%
# Mengisi baris yang memiliki null value di kolom "Kurzarbeit hours per week" dengan nilai "0"
df['Kurzarbeit hours per week'].fillna(0, inplace=True)

# Menampilkan lima baris teratas setelah mengisi nilai null
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Timestamp                            1253 non-null   object
#  1   Age                                  1226 non-null   float64
#  2   Gender                               1243 non-null   object
#  3   City                                 1253 non-null   object
#  4   Position                             1247 non-null   object
#  5   Total experience                     1230 non-null   float64
#  6   Experience in Germany                1194 non-null   float64
#  7   Seniority level                      1241 non-null   object
#  8   Main programming language            1126 non-null   object
#  9   Other programming languages          1096 non-null   object
#  10  Yearly brutto salary                 1253 non-null   float64
# ...

# %% [markdown]
# ChatGPT Prompt : Beri kode untuk menampilkan pie diagram chart untuk fitur Age dengan min 20, max 69

# %%
import matplotlib.pyplot as plt

# Diskritisasi usia menjadi beberapa kelompok
bins = [20, 30, 40, 50, 60, 70]
labels = ['20-29', '30-39', '40-49', '50-59', '60-69']
df['Age_group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Hitung jumlah pengamatan dalam setiap kelompok usia
age_counts = df['Age_group'].value_counts()

# Buat pie chart
plt.figure(figsize=(8, 8))
plt.pie(age_counts, labels=age_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribusi Kelompok Usia')
plt.axis('equal')  # Memastikan pie chart berbentuk lingkaran
plt.show()

# %% [markdown]
# ChatGPT Prompt : beri kode untuk menampilkan baris data yang memiliki Age "51-60" dan "60+"

# %%
# Memilih baris data yang memiliki nilai "51-60" atau "60+" pada kolom "Age_group"
age_51_60 = df.loc[df['Age_group'] == '50-59']
age_60_plus = df.loc[df['Age_group'] == '60-69']

# Menggabungkan hasil pemilihan baris
baris_data = pd.concat([age_51_60, age_60_plus])

# Menampilkan baris data yang telah dipilih
baris_data
# Out:
#                 Timestamp   Age Gender        City           Position   \
# 23    24/11/2020 11:23:11  59.0   Male      Berlin   Backend Developer
# 232   24/11/2020 13:53:01  56.0   Male  Ingolstadt   Software Engineer
# 233   24/11/2020 13:54:47  53.0   Male   Stuttgart  Frontend Developer
# 403   24/11/2020 19:48:24  50.0   Male      Berlin   Software Engineer
# 673   25/11/2020 18:56:02  51.0   Male      Berlin   Software Engineer
# 955   30/11/2020 12:56:08  54.0   Male      Milano              Sales
# 1159  14/12/2020 08:55:24  56.0   Male      Munich   Software Engineer
# 1182  20/12/2020 01:48:34  54.0   Male      Munich   Software Engineer
# 1232  08/01/2021 16:12:36  52.0   Male   Stuttgart   Software Engineer
# 59    24/11/2020 11:33:51  66.0   Male      Munich   Software Engineer
# 296   24/11/2020 15:39:13  65.0   Male      Berlin   Software Engineer
# 1103  06/12/2020 21:51:21  69.0   Male   Stuttgart             Rentner
#
# ...

# %% [markdown]
# ChatGPT Prompt : buatkan kode untuk visualisasi histogram, box plot, scatter plot untuk memahami distribusi dan hubungan antar variabe

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['Total experience'], bins=20, kde=True)
plt.title('Distribusi Total Pengalaman')
plt.xlabel('Total Years of Experience')
plt.ylabel('Frequency')
plt.show()

# Box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Experience in Germany', y='Yearly bonus and stocks', data=df)
plt.title('Hubungan antara Pengalaman di Jerman dan Bonus Tahunan + Saham')
plt.xlabel('Experience in Germany')
plt.ylabel('Yearly Bonus + Stocks (EUR)')
plt.show()

# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Total experience', y='Yearly brutto salary', data=df)
plt.title('Hubungan antara Total Pengalaman dan Gaji Bruto Tahunan')
plt.xlabel('Total Years of Experience')
plt.ylabel('Yearly Brutto Salary (EUR)')
plt.show()

# %% [markdown]
#  ChatGPT Prompt : buatkan heatmap untuk memvisualisasikan korelasinya antar kolom

# %%
# Memilih hanya kolom-kolom numerik
numeric_df = df.select_dtypes(include='number')

# Menghitung korelasi antar kolom dalam dataframe numerik
correlation_matrix = numeric_df.corr()

# Membuat heatmap untuk memvisualisasikan korelasi antar kolom
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap Korelasi Antar Kolom')
plt.show()
